# %% [markdown]
# <a href="https://colab.research.google.com/github/AayushiBr/Python/blob/main/Seaborn%20Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.displot([0,1,2,3,4,5])

# %%
plt.show()
